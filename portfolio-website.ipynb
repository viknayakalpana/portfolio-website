# %% [markdown]
# <a href="https://colab.research.google.com/github/viknayakalpana/portfolio-website/blob/main/portfolio-website.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
2 + 3
# Out:
# 5

# %%
x = 10
y = 5
x + y
# Out:
# 15

# %%
name = "Alex"
print("My name is", name)
# Out:
# My name is Alex
